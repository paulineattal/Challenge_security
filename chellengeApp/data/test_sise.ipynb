# %%
import pandas as pd
import re

# %%
filename = "C:/Users/pauli/Documents/M2/secu/challenge/Challenge_security/chellengeApp/pages/test_sise.txt"

# %%
with open(filename) as file:
    lines = file.read()

log_regex= r'(\S+\s+\S+)\s+(\S+)\s+(\S+)\s+(\S+:\d+)\s+(\S+)\s+(\S+)\s+(\S+)\s+\[(.+)\]\s+"(.+)"\s+(\d+)\s+(\S+)\s+"(.+)"\s+"(.+)"'

log_list = re.findall(log_regex, log_data, re.MULTILINE)

df = pd.DataFrame(log_list, columns = ['datetime', 'ip', 'user', 'server', 'local_ip', 'client_id', 'user_id', 'request_datetime', 'request', 'status', 'response_size', 'referrer', 'user_agent'])
print(df)
# Out:
#          datetime           ip     user  \
# 0     23 09:31:12  28.28.28.90  apache:
# 1     23 09:32:02  28.28.28.90  apache:
# 2     23 09:32:03  28.28.28.90  apache:
# 3     23 09:32:21  28.28.28.90  apache:
# 4     23 09:32:33  28.28.28.90  apache:
# ...           ...          ...      ...
# 9991  23 17:41:25  28.28.28.90  apache:
# 9992  23 17:41:25  28.28.28.90  apache:
# 9993  23 17:41:25  28.28.28.90  apache:
# 9994  23 17:41:25  28.28.28.90  apache:
# 9995  23 17:41:25  28.28.28.90  apache:
#
#                                      server         local_ip client_id  \
# 0                            market.com:443    51.222.253.20         -
# 1     ip-28-28-28-90.ip.secureserver.net:80        127.0.0.1         -
# 2                            market.com:443   178.135.11.175         -
# 3                            market.com:443    51.222.253.16         -
# 4                            market.com:443    35.186.38.239         -
# ...

# %%
df.to_csv("data_test.csv", index=False)

# %%
seachfor_agent = ['curl', 'python', 'bvega', 'openvas', 'map']
seachfor_attack = ['\/etc\/passwd','/etc','/\*', '#']
seachfor_webshell = ['\<form', '\<\%', '\<\?', '\<php', 'shell\?', 'chmod\+', '777']
seachfor_admins = ['admin', 'root', 'superuser']
seachfor_xss = ['alert', 'script']
seachfor_sql = ['--\'','\'--', 'exec', 'select', 'insert', 'update', 'delete', 'drop', 'where', 'dbo', 'cast\(', 'char\(']


pattern_agent
pattern_a
pattern_admin
pattern_sql
pattern_webshell
pattern_xss

Bot = data[data['agent'].str.contains('Bot', case=0)]
list_bot = pd.DataFrame(Bot['agent'].unique())

find=data[data['clientip'].str.contains('78.159.96.193', case=0)]

#data = ...



#ip_server ="192.169.195.95“
##### attack ou login admin

type_wpress=data[data['rawrequest'].str.contains('wp-', case=0)].reset_index().fi11na(0)
type_attack=data[data['rawrequest'].str.contains(pattern_a, case=0)] .reset_index().fillna(0)# & ~datal'clicntip'].str.contains(ip_sc
type_admin=data[data['rawrequest'].str.contains(pattern_admin, case=0)].reset_index().fillna(0)
#stat_admin=type_admin['clientip'l.value_counts().reset_index().f111na(0)
type_sq1=data[data['nawrequest'].str.contains(pattern_sql, case=0)].reset_index().fillna(0)
type_sq1=data[data['rawrequest'].str.contains(pattern_sql, case=0)].reset_index().fillna(0)
type_xss=data[data['rawrequest'].str.contains(pattern_xss, case=0)].reset_index().f111na(0)
type_webshell=data[data['rawrequest'].str.contains(pattern_webshell, case=0)].reset_index().fillna(0)
type_agent=data[data['agent'].str.contains(pattern_agent, case=0)].reset_index().fillna(0)

q1= """"select clientip, count(*) as nombre, count(distinct response) as cnbresp,
sum( case when response >= 499 then 1 ENU) as resp_denyz sum( case when response between 190 and 199 then 1 EMU) as resprovi,
sum( case when response between 200 and 299 then 1 ENU) as resp_ok,
sum( case when response between 300 and 399 then 1 ENU) as rcsp_rcdirect,
sum( case when verb LIKE 'GET’ then 1 ENU) as v_get,
sum( case when verb LIKE 'POST' then 1 ENd) as v_post,
sum( case when verb LIKE 'HEAD' then 1 ENd) as v_head, 
sum( case when verb <> 'POST' and verb <> 'GET' and verb <> 'HEAD' then 1 ENd) as v_other
from data group by clientip """

analyse=(ps.sqldf(q1, locals()))
analyse=analyse.fillna(0)
wpress_a=type_wpress['clientip'].value_counts().reset_index().fillna(0)
analyse['wpress']=np.nan
analyse['root_a']=np.nan
analyse['admin']=np.nan
analyse['xss']=np.nan
analyse['agent_p']=np.nan
analyse['webshell']=np.nan
#(analyse.clientip)

wpress_a=wpress_a.rename(columns = {'clientip':'nbr', 'index':'clientip'})

for index,ligne in wpress_a.iterrows():
    for index,lg in analyse.iterrows():
        if ligne['clientip'] == lg['cZientip']:
            lg.wpress = ligne.nbr
            analyse.loc[index, 'wpress'] = ligne.nbr
                                                                               
root_a=type_attack['clientip'].value_counts().reset_index().fillna(0)
root_a=root_a.rename(columns = {'clientip':'nbr', 'index':'clientip'})


admin_a=type_admin['clientip'].value_counts().reset_index().fillna(0)
admin_a=admin_a.rename(columns = {'clientip':'nbr', 'index':'clientjp'})

xss_a=type_xss['clientip'].value_counts().reset_index().fillna(0)
xss_a=xss_a.rename(columns = {'clientip':'nbr', 'index':'clientip'})

agent_a=type_agent['clientip'].value_counts().reset_index().fillna(0)
agent_a=agent_a.rename(columns = {'clientip':'nbr', 'index':'clientip'})
                   


she11_a=type_webshell['clientip'].value_counts().reset_index().fitlna(0)
she11_a=shell_a.rename(columns = {'clientip':'nbr', 'index':'clientip'})



#sum(casc when action like 'Dcny' then 1 ENd) as deny,
#sum(case when action like 'Deny' and dstport < 1024 then 1 ENd) as inf1824deny,
#sum(case when action like 'Deny' and dstport >= 1824 then 1 ENd) as sup1024deny,
#sum( case when action like 'Deny' and (dstport = 21 OR dstport = 22 OR dstport = 3389 OR dstport = 3306) then 1 ENd) as admindeny
for index,ligne in root_a.iterrows():
    for index,lg in analyse.iterrows():
        if ligne['clientip'] == lg['cientip']:
            analyse.loc[index,'root_a'] = ligne.nbr

for index,ligne in admin_a.iterrows():
    for index,lg in analyse.iterrows():
        if ligne['clientip'] == lg['clientip']:
            #lg.admin = ligne.nbr
            analyse.loc[index, 'admin'] = ligne.nbr


for index,ligne in xss_a.iterraws():
    for index,lg in analyse.iterrows():
        if ligne['clientip'] == lg['clientip']:
            #lg.xss = ligne.nbr
            analyse.loc[index, 'xss'] = ligne.nbr

for index,ligne in agent_a.iterrows():
    for index,lg in analyse.iterrows():
        if ligne['clientip'] == lg['clientip']:
            #lg.agcnt_p = lignc.nbr
            analyse.loc[index, 'agent_p'] = ligne.nbr

for index,ligne in she11_a.iterrows():
    for index,lg in analyse.iterrows():
        if ligne['clientip'] == lg['clientip']:
            #lg.shell_a = ligne.nbr
            analyse.loc[index, 'webshell'] = ligne.nbr

                                  
analyse=analyse.fillna(0)


analyse.to_csv('', index = False)

expert = pd . read_csv( "/model_web.csv", sep=";")
del expert['nombre']
                                  
X=expert[['resp_deny', 'resp_provi', 'resp_ok', 'resp_redirect', 'v_get', 'v__pqst', 'v_head', 'v_other', 'wpress', 'root_a', 'admin']]
y=expert['risque']

#cnbripdst+inf1024permit+sup1024permit+adminpermit+inf1024deny+sup1024deny+admihdeny
#apres train_test_split
#faire un random forest
#retourner les metrics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 9
#       5 seachfor_xss = ['alert', 'script']
#       6 seachfor_sql = ['--\'','\'--', 'exec', 'select', 'insert', 'update', 'delete', 'drop', 'where', 'dbo', 'cast\(', 'char\(']
# ----> 9 pattern_agent
#      10 pattern_a
#      11 pattern_admin
#
# NameError: name 'pattern_agent' is not defined
